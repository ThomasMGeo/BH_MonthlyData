# %%
import pandas as pd
import matplotlib as plt

# %%
# Have the change file name, no spaces!
filename = 'Rigs_by_State_012519.xlsx'

# %%
df = pd.read_excel(filename) # kinda a big df

# %%
xls = pd.ExcelFile(filename)
sheets = xls.sheet_names

# %%
type(sheets)
# Out:
# list

# %%
# getting rid of columns 
df = df.drop(columns=['Unnamed: 2','Unnamed: 4','Unnamed: 6','Unnamed: 8', 'Unnamed: 10'])

# %%
df
# Out:
#                                          BAKER HUGHES           Unnamed: 1  \
# 0                      ROTARY RIGS RUNNING - BY STATE                  NaN
# 1                                                 NaN                  NaN
# 2                                 2019-01-01 00:00:00                  NaN
# 3                                                 NaN  2019-01-04 00:00:00
# 4                                        ALABAMA-LAND                    2
# 5                                   ALABAMA-INL WATER                    0
# 6                                    ALABAMA-OFFSHORE                    0
# 7                                       TOTAL ALABAMA                    2
# 8                                         ALASKA-LAND                    9
# 9                                     ALASKA-OFFSHORE                    0
# 10                                       TOTAL ALASKA                    9
# ...

# %%
# 13 is CA Land
# 16 is Colorado
# 63 is Utah
# 67 is Wyoming

CA_avg = df.iloc[13,5]

# df.iloc[13]
# Out:
# 8

# %%
sheets
# Out:
# ['Jan 19',
#  'Dec 18',
#  'Nov 18',
#  'Oct 18',
#  'Sep 18',
#  'Aug 18',
#  'Jul 18',
#  'Jun 18',
#  'May 18',
#  'Apr 18',
#  'Mar 18',
#  'Feb 18',
#  'Jan 18',
#  'Dec 17',
#  'Nov 17',
#  'Oct 17',
#  'Sep 17',
#  'Aug 17',
#  'Jul 17',
#  'Jun 17',
#  'May 17',
#  'Apr 17',
#  'Mar 17',
#  'Feb 17',
#  'Jan 17',
#  'Dec 16',
#  'Nov 16',
#  'Oct 16',
#  'Sep 16',
#  'Aug 16',
#  'Jul 16',
#  'Jun 16',
#  'May 16',
#  'Apr 16',
#  'Mar 16',
#  'Feb 16',
#  'Jan 16',
#  'Dec 15',
#  'Nov 15',
#  'Oct 15',
#  'Sep 15',
#  'Aug 15',
#  'Jul 15',
#  'Jun 15',
#  'May 15',
#  'Apr 15',
#  'Mar 15',
#  'Feb 15',
#  'Jan 15',
#  'Dec 14',
#  'Nov 14',
#  'Oct 14',
#  'Sep 14',
#  'Aug 14',
#  'Jul 14',
#  'Jun 14',
#  'May 14',
#  'Apr 14',
#  'Mar 14',
#  'Feb 14',
#  'Jan 14',
#  'Dec 13',
#  'Nov 13',
#  'Oct 13',
#  'Sep 13',
#  'Aug 13',
#  'Jul 13',
#  'Jun 13',
#  'May 13',
#  'Apr 13',
#  'Mar 13',
#  'Feb 13',
#  'Jan 13',
#  'Dec 12',
#  'Nov 12',
#  'Oct 12',
# ...
